# %% [markdown]
# # N-Gram Models

# %%
from random import randint
from math import log, exp, prod
from pprint import pprint

from sklearn.model_selection import train_test_split
from nltk import ngrams
from indicnlp.tokenize.indic_tokenize import trivial_tokenize
from indicnlp.tokenize.sentence_tokenize import sentence_split

# %% [markdown]
# ## Normalizing the text

# %% [markdown]
# ## Maximum Likelihood Estimation
# - The maximum likelihood of a sequence $$w_{i-n+1},\dots ,w_{i-2},w_{i-1},w_i$$ is the likelihood of $w_i$ coming after the sequence $$w_{i-n+1},\dots ,w_{i-2},w_{i-1}$$
# - Thus,
# $$
# P(w_i|w_{i-n+1},\dots ,w_{i-2},w_{i-1}) = \frac{
#     C(w_{i-n+1},\dots ,w_{i-2},w_{i-1},w_i)
#     }{
#         \sum_w C(w_{i-n+1},\dots ,w_{i-2},w_{i-1},w)
#     }
# $$
# - Now, the number of n-grams starting with $w_{i-n},\dots ,w_{i-2},w_{i-1}$ is the same as the number of times the sequence appears, thus $$  \sum_w C(w_{i-n},\dots ,w_{i-2},w_{i-1},w) = C(w_{i-n},\dots ,w_{i-2},w_{i-1}) $$
# - Thus, the MLE becomes
# $$
# P(w_i|w_{i-n+1},\dots ,w_{i-2},w_{i-1}) = \frac{
#     C(w_{i-n+1},\dots ,w_{i-2},w_{i-1},w_i)
#     }{
#         C(w_{i-n+1},\dots ,w_{i-2},w_{i-1})
#     }
# $$

# %%
class NGramModel:
    def __init__(self, text: str, n: int, keep_punctuation: bool=False, verbose: bool=False):
        self.text = text
        self.n = n
        self.verbose = verbose
        self.keep_punctuation = keep_punctuation
        sentences, words = self._tokenize(text)
        self.vocabulary = list(set(words))
        self.n_grams = self._make_n_grams(sentences, n)
        self.n1_grams = self._make_n_grams(sentences, n-1)
        # if self.verbose:
            # pprint(self.n_grams)

    def _tokenize(self, text: str):
        sentences = [
            trivial_tokenize(sentence)
                for sentence in sentence_split(text, lang='hi')
        ]
        
        punctutation=['.', ',', '!', '?', '।']
        words = [
            word
                for sentence in sentences
                    for word in sentence
        ]

        sentences = [(
            ['<s>']*(self.n-1) + sentence + ['</s>']*(self.n-1)
        ) for sentence in sentences]

        if not self.keep_punctuation:
            sentences = [
                [word for word in sentence
                    if word not in punctutation]
                for sentence in sentences
            ]
            words = [
                word for word in words
                    if word not in punctutation
            ]
        return sentences, words

    def _make_n_grams(self, sentences: list[list[str]], n: int) -> list[tuple[str, ...]]:
        n_grams = [
            ng for sentence in sentences
                for ng in ngrams(sentence, n)
        ]
        return n_grams

    def getMLE(self, word: str, prev_words: tuple[str]) -> float:
        if len(prev_words) >= self.n:
            raise ValueError('prev_words should have length n-1')
        if len(prev_words) < self.n-1:
            prev_words = ('<s>',)*(self.n-1-len(prev_words)) + prev_words
        sequence = tuple(prev_words+(word,))
        count_sequence = self.n_grams.count(sequence)
        count_prev = self.n1_grams.count(prev_words)
        if count_prev == 0:
            mle = 0
        else:
            mle = count_sequence/count_prev
        if self.verbose:
            pprint({
                'seq': sequence,
                'cs': count_sequence,
                'prev': prev_words,
                'cp': count_prev,
                'mle': mle
            })
        return mle

    def getSentenceProb(self, sentence: str) -> float:
        tokenized_sentence, _ = self._tokenize(sentence)
        s = tokenized_sentence[0]
        prob_pairs = [(
            sent,
            tuple(s[i-self.n+1:i])
        ) for i, sent in enumerate(s)][self.n-1:]
        prob = prod([self.getMLE(*pair) for pair in prob_pairs])
        # prob = exp(sum([log(self.getMLE(*pair)) for pair in prob_pairs]))
        return prob
    
    def _generateWord(self, last_n_words: tuple[str], top_n):
        word_probs = [(word, self.getMLE(word, last_n_words)) for word in self.vocabulary]
        best_words = sorted(word_probs, key=lambda x: x[1], reverse=True)[:top_n]
        # print(best_words)
        rand_ind = randint(0, top_n - 1)
        next_word = best_words[rand_ind][0]
        return next_word

    def generateNextWord(self, words: str, top_n: int):
        last_n_words = words[-self.n: ]
        return self._generateWord(tuple(last_n_words), top_n)

    def generateText(self, seed_words: str, length: int, top_n: int=3):
        last_n_words = seed_words[-self.n: ]
        text = " ".join(seed_words) + " "
        for i in range(length):
            new_word = self._generateWord(tuple(last_n_words), top_n)
            last_n_words = last_n_words[1:] + [new_word]
            text += new_word + " "
        return text

# %% [markdown]
# ## MLE Prediction

# %%
text = ''
with open('datasets/iit_bombay/dev_test/dev.hi', 'r') as file:
    text = file.read()

# %%
text = text.split('\n')
_, test_text = train_test_split(text, train_size=0.7)
text = "\n".join(text)
test_text = "\n".join(test_text)

# %%
print(len(text.split('\n')))
text
# Out:
# 521
# 'महानगर पालिका अंतर्गत दत्तात्रय नगर माध्यमिक स्कूल के विद्यार्थियों ने काल्पनिक किला \'दत्तगढ़\' बनाकर अपनी कल्पनाशक्ति का परिचय दिया।\nप्रधानाध्यापक संध्या मेडपल्लीवार के प्रोत्साहित करने पर शिक्षकों व विद्यार्थियों ने मिट्टïी से किले का निर्माण किया।\nमनपा शिक्षक संघ के अध्यक्ष राजेश गवरे ने स्कूल को भेंट देकर सराहना की।\nकिले का परीक्षण रमेश सातपुते ने किया।\nकिला निर्माण में निखिल कावले, दर्शन गेड़ेकर, साहिल मेश्राम इन विद्यार्थियों ने सहभाग लिया।\nजिला कलाध्यापक संघ के अध्यक्ष नरेंद्र बारई, कोषाध्यक्ष शेखर वानस्कर, सदस्य अजय गुंडमवार, गजानन मेहर ने विद्यार्थियों का मार्गदर्शन किया।\nनगरसेवक रीता मुले ने सदिच्छा भेंट दी।\nरोहतक. नौकरियों में भ्रष्टाचार, फर्जीवाड़े व लूट- खसोट के खिलाफ अखिल भारतीय जनवादी महिला समिति और डीवाईएफआई ने संयुक्त रूप से प्रदेशव्यापी अभियान शुरू किया है।\nइस राज्यव्यापी हस्ताक्षर अभियान के माध्यम से प्रदेश भर में 10 लाख हस्ताक्षर करवाकर राज्यपाल को सौंपे जाएंगे।\nशुक्रवार को नए बस स्टैंड पर हस्ताक्षर अभियान की शुरुआत की गई।\nइस मौके पर एसएफआई के राज्य सचिव मनोज कुमार, समिति की जिला सचिव अ
ंत्रियों को शामिल किया।\nउनके नाम पर सड़क, विश्वविद्यालय या हवाई अड्डों की पहचान बेशक स्वागत योग्य है, लेकिन एक ही राजनीतिक परिवार के नाम पर ग्रामीण आवास योजना से लेकर देश की राजधानी के अंतरराष्ट्रीय हवाई अड्डे का नामकरण किसी भी सूरत में उचित नहीं कहा जा सकता।\nगंगा अपनी बहन से मिलने मुंबई जा रही थी तथा मुंबई के लिए चंडीगढ़ से दोपहर बाद उसकी फ्लाइट थी।\nबाम्बे स्टॉक एक्सचेंज का सेंसेक्स 130.50 अंक उछलकर 21,164.52 अंक के स्तर पर और नेशनल स्टॉक एक्सचेंज का निफ्टी 47.45 अंक ऊपर 6299.15 अंक के स्तर पर जा चढ़ा।\nकई आवेदक ऐसे भी हैं जिन्हें ९ महीने के बाद भी डीएल डिलीवर नहीं हो पाया।\nदोनो ...

# %%
bigram_model = NGramModel(text, 2)

# %%
bigram_model.getMLE('समय', ('उस',))
# Out:
# 0.6666666666666666

# %% [markdown]
# ## Sentence Prediction

# %%
bigram_model.getSentenceProb('शुक्रवार को छोटी दिवाली यानी की धनतेरस है।')
# Out:
# 4.6126843477351237e-10

# %%
bigram_model.getSentenceProb('शुक्रवार को छोटी दिवाली यानी की धनतेरस है')
# Out:
# 4.6126843477351237e-10

# %%
bigram_model.getSentenceProb('स्कूल को छोटी दिवाली यानी की धनतेरस है।')
# Out:
# 1.4192874916108074e-11

# %% [markdown]
# ## Text Generation

# %%
bigram_model.generateNextWord(['को'], 3)
# Out:
# 'इस'

# %%
bigram_model.generateText(['को'], 20)
# Out:
# 'को भी हैं तो बिजली निगम ने अपने मंत्रिमंडल का आयात शुल्क मूल्य बढ़ाकर 738 सभ्यता और बरगी विधानसभा को लेकर '

# %%
bigram_model.generateText(['पर'], 20)
# Out:
# 'पर शांति सभ्यता और अनारक्षित वेस्ट सभ्यता वेस्ट वेस्ट वेस्ट दिलबाग वेस्ट दिलबाग वेस्ट सभ्यता सभ्यता और पेंशन सभ्यता वेस्ट दिलबाग '

# %%
bigram_model.vocabulary
# Out:
# ['सभ्यता',
#  'वेस्ट',
#  'संवैधानिक',
#  'लाभ',
#  'रिवीजन',
#  'रोगी',
#  'विश्वविद्यालय',
#  'अकाउंटेंट्स',
#  'जब',
#  'ओवर',
#  'जरिए',
#  'शिकंजा',
#  'उनकी',
#  'मृदुला',
#  'डाली',
#  'सवाल',
#  'मैदान',
#  'बीच',
#  'कह',
#  'पाई',
#  'दास',
#  'मर्जी',
#  'ग्राम',
#  'खरीदते',
#  'हजारों',
#  '1.5',
#  'प्रत्याशियों',
#  'बागवानी',
#  'रहे',
#  'लगे',
#  'सुनाई',
#  'महीने',
#  'प्रकार',
#  '31',
#  'सामने',
#  'अभियान',
#  'चोरी',
#  'सेल',
#  'गुम',
#  'महाप्रबंधक',
#  'केन्ट',
#  'हरीश',
#  'रेवन्यू',
#  'काफी',
#  'चचेरी',
#  'अभेद',
#  'अजय',
#  'लगातार',
#  'सप्ताह',
#  'चली',
#  'किताब',
#  'नागरिक',
#  'जिस',
#  'डीटीओ',
#  'सहकारिता',
#  'महापुरुष',
#  'बार',
#  'प्रेरक',
#  'आज',
#  'कानून',
#  'पद',
#  'टैक्सी',
#  'चीख',
#  'कराए',
#  'मुनाफे',
#  'दुर्गा',
#  'बताने',
#  'खिलाफ',
#  'रिजर्व',
#  'मुहल्ला',
#  'सोनकर',
#  'फीस',
#  'बाड़वाला',
#  'ऊपर',
#  'ऑफ',
#  'जेल',
#  'उखाड़कर',
#  'अधिक',
#  'राजव्यवस्थाएं',
#  'वनस्पति',
#  'विकसित',
#  'स्कूल',
#  'जोड़ा',
#  'टांगों',
#  'एवं',
#  'भरना',
#  'मिला',
#  'पीएम',
#  'चलाकर',
#  'देनी',
#  'नौकरशाही',
#  'संयुक्त',
#  'खराब',
#  'साहित्य',
#  'समझनी',
#  'स्वागत',
#  "'",
#  'ड्यूटी',
#  'बढ़ती',
#  'डॉलर',
#  'बनाने',
#  'कन्नूर',
#  'मतदाता',
#  'आरबीडी',
#  'पास',
#  'अतिरिक्त',
#  'परीक्षण',
#  'पूर्वजों',
#  'चाहता',
#  'यात्री',
#  'हाजरी',
#  'डीए',
#  'संसद',
#  'मंजीत',
#  'यादव',
#  'मंडी',
#  'व्यक्तित्वों',
#  'आफत',
#  'मई',
#  'आवेदक',
#  '15',
#  'गरीब',
#  'घटनाक्रम',
#  'मध्य',
#  'श्रीमद्कथा',
#  'विरासत',
#  'हमलों',
#  'घटनाएं',
#  'व्यक्तित्व',
#  'बजे',
#  'मिलने',
#  'लेने',
#  'पिछले',
#  'अक्टूबर',
#  'जीवन',
#  'देवकांत',
#  'धधंवा',
#  'अब्दुल',
#  'बदतर',
#  '/',
#  'सिंह',
#  'नेहरू',
#  'रणजीत',
#  'होगी',
#  'शोध',
#  '9',
#  'सुस्त',
#  '442',
#  'तरुण',
#  'वो',
#  'घर',
#  '38',
#  'संग्राम',
#  'रिटायरमेंट',
#  'प्रतिष्ठित',
#  'हरी',
#  'दीवाली',
#  'जबकि',
#  'उपहार',
#  'ललेयाल',
#  'चौथी',
#  'उपदेश',
#  'पूछ',
#  'लेकर',
#  'आखिरकार',
#  'बुरी',
#  '80',
#  'देखी',
#  'इलाके',
#  'मील',
#  'धातु',
#  'पालिका',
#  'परिजनों',
#  'करना',
#  'बेटी',
#  'सातपुते',
#  'विदेशी',
#  'कहे',
#  'चलन',
#  'करेगा',
#  'व्यक्ति',
#  'खुश',
#  'पटीशन',
#  'स्वतंत्रता',
#  'मनाली',
#  'प्रो',
#  'मंत्री',
#  'नया',
#  'कार्रवाई',
#  'विपिन',
#  'सुनीता',
#  'चलाईं',
#  'बढ़ा',
#  'मूल',
#  'किराए',
#  'चर्चित',
#  'अगले',
#  'पीडीएस',
#  'प्रमोद',
#  'सरलतम',
#  'दोपहर',
#  'बनती',
#  'वक्त',
#  'थाना',
#  'बिजली',
#  'पॉम',
#  'इसे',
#  'वनवास',
#  'धमाकों',
#  'कारण',
#  'अनगिनत',
#  'जाएगा',
#  'लौटने',
#  'नीतीश',
#  'समीप',
#  'चड़िया',
#  'कालसी',
#  '९',
#  'गहरी',
#  'गार्डन',
#  'बाल',
#  'हेड',
#  'गोविंददास',
#  'रिन्युअल',
#  'खामियां',
#  'डिलीवर',
#  'कहा',
#  'एशान',
#  'बड़ा',
#  'सोनू',
#  'बहस',
#  'माने',
#  'अटक',
#  'दूसरी',
#  '31,400',
#  'किसान',
#  'प्राचीन',
#  'पदाधिकारी',
#  'कारवाई',
#  'प्रभावकारी',
#  'तय',
#  'पोस्टमार्टम',
#  'प्रोत्साहित',
#  'पथ',
#  'दोषी',
#  'डरावने',
#  'यानी',
#  'चयनकर्ताओं',
#  'चुनकर',
#  'सकते',
#  'भागे',
#  'मानें',
#  'रिक्वीजिशन',
#  'बोधगया',
#  'टू',
#  'पत्नी',
#  'सीपीआरओ',
#  'शोर',
#  'आवेदन',
#  'मैनपुरी',
#  'वैश्रि्वक',
#  '\nराजनीतिक',
#  'मांगों',
#  'लाई',
#  'लोकमान्य',
#  'कामना',
#  'पूरा',
#  'पेड़',
#  'लेती',
#  'आरोप',
#  'अमेरिका',
#  'संस्थान',
#  'सीएडीपी',
#  '1950',
#  'रहा',
#  'मुकाबले',
#  'छोटे',
#  'राजमार्ग',
#  'प्रसाद',
#  'सुशील',
#  'ध्यान',
#  'अटकलें',
#  'बंद',
#  'दयानंद',
#  'विट्ठल',
#  'दूसरे',
#  'जगहों',
#  'लंबी',
#  'नंगल',
#  'अहिंसा',
#  'पार्टियों',
#  'जूं',
#  'मार्गदर्शन',
#  'रखने',
#  'गठन',
#  'रख',
#  'निर्देश',
#  'साथ',
#  'यूटी',
#  'दमकल',
#  'होने',
#  'बारई',
#  'बैठक',
#  'गौरवशाली',
#  'गांधीनगर',
#  'पीएचई',
#  'ए',
#  'हरेक',
#  'उपलब्धि',
#  'अमित',
#  'जोशी',
#  'दुरुपयोग',
#  'आयोजित',
#  'पार्षद',
#  'अनेक',
#  '4',
#  '58',
#  'सुंदरनगर',
#  'चढ़ा',
#  'चलाने',
#  'मृत्यु',
#  'भिन्नता',
#  'धरपकड़',
#  'आचारशास्त्र',
#  'जबर्दस्त',
#  'एसडीएम',
#  'लगाते',
#  'अर्थव्यवस्था',
#  'पेंशन',
#  'थाने',
#  'पावरमैन',
#  '83.6',
#  'मिलेंगे',
#  'सकती',
#  'गर्ग',
#  'आर्थिक',
#  'मद्देनजर',
#  'नरहरी',
#  'नायब',
#  'विद्यार्थियों',
#  'थे',
#  'बरतने',
#  'जागरण',
#  'निर्भर',
#  'तैनात',
#  'काम',
#  'गए',
#  'डिविजन',
#  'सकेगा',
#  'मात्र',
#  'ताजगंज',
#  'मानक',
#  'साढ़े',
#  'सुरेंद्र',
#  'दृष्टिकोण',
#  'राजबीर',
#  'नौकरियों',
#  'जाती',
#  'बेलाटांड़',
#  'सुभाष',
#  'कॉलेज',
#  'देख',
#  'विवेकानंद',
#  'गिल',
#  'अधिकार',
#  'निर्माणाधीन',
#  'अवनि',
#  'काउंटर',
#  '72.5',
#  'आने',
#  'हरिपुर',
#  'सरकार',
#  'बनाया',
#  'बतानी',
#  'भरा',
#  '738',
#  'लगाकर',
#  'संगत',
#  'मानसिक',
#  'तेरहवें',
#  'पंजाबियों',
#  'पांडे',
#  'कनेक्शन',
#  'वीरवार',
#  'अभिभावकों',
#  'सराहना',
#  'शहीदों',
#  'खाली',
#  'फोन',
#  'दर्शनविद',
#  'नए',
#  'अंतरिम',
#  'अंधेरे',
#  'हुए',
#  'करदाता',
#  'संबोधित',
#  'तहसीलदारों',
#  'यात्रा',
#  'शांति',
#  'सेंट',
#  'स्थापना',
#  'काबू',
#  'कुलभूषण',
#  'केवल',
#  'पटाखा',
#  'द्विपक्षीय',
#  '47.45',
#  'प्रेरित',
#  'जेवरों',
#  'भरपूर',
#  'सदस्यीय',
#  'बच्ची',
#  'अधिकारियों',
#  'जून',
#  'स्क्रिप्ट',
#  'आदेश',
#  'उपस्थित',
#  'वित',
#  'दयनीय',
#  'सकेगी',
#  'बर्तन',
#  'छोड़कर',
#  'लालू',
#  'तैयार',
#  '130.50',
#  'मीडिया',
#  'ऐसे',
#  'इनमें',
#  'बराबर',
#  'बहादुर',
#  'जुलाई',
#  'ग्रहण',
#  'पखवाड़े',
#  'बैठे',
#  'वेशभूषा',
#  'तिलक',
#  'अच्छे',
#  'ढंग',
#  'मंहगा',
#  'बनी',
#  'लहजा',
#  'राजनीतिक',
#  'एमडी',
#  'जिसके',
#  'रमेश',
#  'तमिल',
#  'पैर',
#  'जुड़ी',
#  'उतार',
#  '21.60',
#  'एक्सईएन',
#  'अपमान',
#  'गैरहाजिर',
#  'कोर्ट',
#  'लाख',
#  'अर्पित',
#  'मूलभूत',
#  '72.1',
#  'इसके',
#  'हिस्से',
#  'नुक्सान',
#  'अगर',
#  '15.12',
#  'हवा',
#  'बाल्यकाल',
#  'न्यायाधिकरण',
#  'कड़े',
#  'फेडरेशन',
#  'कठा',
#  'पागल',
#  'प्रमाण',
#  'भेजकर',
#  'ऊंचाई',
#  'लूट',
#  'महानता',
#  'मेरी',
#  '21',
#  'वहीं',
#  'ऑल',
#  'अनियमितता',
#  'संस्थागत',
#  'खरीद',
#  'कुल',
#  'गेड़ेकर',
#  'ओर',
#  'पारा',
#  'जो',
#  'जानने',
#  'दीपक',
#  'रोहतक',
#  'गुप्ता',
#  'पति',
#  'अड्डों',
#  'च्यादा',
#  'फंदा',
#  'महंगाई',
#  'साहिल',
#  'खुलवाया',
#  'सुनकर',
#  'यात्राएं',
#  'माननीय',
#  'बिकते',
#  'योजनाओं',
#  'मारी',
#  'पंजाबी',
#  'ट्रैफिक',
#  'नोटिस',
#  '562',
#  'अभी',
#  'चलिए',
#  'सोनी',
#  'अलावा',
#  'बर्दाश्त',
#  'घरवालों',
#  'हवाई',
#  'केवी',
#  'विपक्षी',
#  'अदालत',
#  'स्वीकृत',
#  'प्रखंड',
#  'अमीन',
#  'घोर',
#  'मोटर',
#  'सहित',
#  'आय',
#  'कमजोर',
#  'छत',
#  'लोगों',
#  'साफ',
#  'साव',
#  'महेन्द्र',
#  'बिहार',
#  'भले',
#  'क्षेत्रों',
#  'पूरे',
#  'मुनेश्वर',
#  'वैदिक',
#  'युवक',
#  'साल',
#  'घायल',
#  'वैज्ञानिक',
#  'मनाया',
#  'दस',
#  'मोबाइल',
#  'रतन',
#  'हीरे',
#  'सीमाशुल्क',
#  'जानकारी',
#  'सूत्रों',
#  'रमेशचंद',
#  'संवाददाता',
#  'करते',
#  'आते',
#  'सदस्यों',
#  'होटल',
#  'की',
#  'विरोध',
#  'करवाया',
#  'प्रदीप',
#  'चल',
#  'तीसरा',
#  'भरोसे',
#  'बताओ',
#  'गुलाम',
#  'प्रधानमंत्री',
#  'अपने',
#  'मोहन',
#  'सुरक्षा',
#  'घोषणा',
#  'घटनास्थल',
#  'मेहुल',
#  'निर्माण',
#  'जूलरी',
#  'बताया',
#  'आता',
#  'ग्रुप',
#  'दर्ज',
#  'बचपन',
#  '102',
#  'जरूरत',
#  'श्रीविधि',
#  'विश्राम',
#  'आगे',
#  'अवतरण',
#  'सघन',
#  'अपील',
#  'लंबे',
#  'महापुरुषों',
#  'बढ़ाकर',
#  'टीमों',
#  'राइटर',
#  'मर्यादा',
#  'आगामी',
#  'तौर',
#  'जयेश',
#  'ने',
#  'इकबाल',
#  'देश',
#  'बारिश',
#  'क्रमशः',
#  'समझौते',
#  'दीप',
#  'पूजा',
#  'प्रवृत्ति',
#  'मान',
#  'मच',
#  'जन्म',
#  'दिमाग',
#  'बढ़ोत्तरी',
#  'बुलाकर',
#  'अंदाज',
#  'दिमुथ',
#  'देहरादून',
#  'दिला',
#  'कामकाज',
#  'स्थल',
#  'जावेद',
#  'वर्मा',
#  'बारी',
#  'पंवार',
#  'सफर',
#  'घरेलू',
#  '699',
#  'गडकरी',
#  'श्रद्धालु',
#  'बेचने',
#  'रजिस्टर',
#  'मां',
#  'मित्रों',
#  'पुनः',
#  'राजनीति',
#  'दवा',
#  'सामान',
#  'दत्तगढ़',
#  'स्तरीय',
#  'महासचिव',
#  'आधे',
#  'ले',
#  'निधन',
#  'शिल्पा',
#  'राशि',
#  'मौजूदा',
#  'आकर्षित',
#  'ज्ञात',
#  'पाने',
#  'लांघने',
#  'उठाया',
#  'लेक्चरर',
#  'फेशियल',
#  'डेडलाइन',
#  'आधा',
#  'पाकिस्तान',
#  'राजनीतिकरण',
#  'प्रतिशत',
#  'स्टे',
#  'उन्हे',
#  'गुड्स',
#  'तोड़ते',
#  'देरी',
#  'चैकिंग',
#  'नियमों',
#  'अपनाते',
#  'अपराधी',
#  'मुख्यालय',
#  'वह',
#  'दिलाने',
#  'वानस्कर',
#  'जैसे',
#  'मंजू',
#  'अरविंद',
#  'शनिवार',
#  'प्रदूषण',
#  'घायलों',
#  'करें',
#  'कैंट',
#  'बैंकों',
#  'नाले',
#  'पहुंचकर',
#  'को',
#  'जहां',
#  'आपूर्ति',
#  'चर्चा',
#  'वर्ग',
#  'कीवियों',
#  'वेदांत',
#  'किन',
#  'पर्यायवाची',
#  'एसई',
#  'सिंगापुर',
#  'दौर',
#  'विभागों',
#  'द्वारा',
#  'कीमतें',
#  'मांगी',
#  'जबाव',
#  'राजनेताओं',
#  'जल',
#  'चलती',
#  'सा',
#  'अन्य',
#  'मंत्रियों',
#  'प्रतिस्पर्धी',
#  'बदनाम',
#  'बीबीएमबी',
#  'इन',
#  'भरने',
#  'सी',
#  'दिख',
#  'साहित्यकार',
#  'गोली',
#  'हितों',
#  'तो',
#  'नामों',
#  'नियुक्ति',
#  'मालवीय',
#  'दाम',
#  'मीटिंग',
#  '24',
#  'चिकित्सकों',
#  'डरावनी',
#  'दक्षिण',
#  'अराजकता',
#  'सर्कल',
#  'हमने',
#  'आवास',
#  'राजेंद्र',
#  'तथा',
#  'वर्षीय',
#  'इधर',
#  'अंचल',
#  'गैस',
#  'थोड़ा',
#  'आंगन',
#  'विश्वकर्मा',
#  'राहत',
#  'संभवतः',
#  'उचित',
#  'मूलरूप',
#  'इस',
#  'विजय',
#  'समारोह',
#  'आत्माएं',
#  'उत्साहित',
#  'प्रतिनिधियों',
#  'किए',
#  'लगाने',
#  'वर्तमान',
#  'समिति',
#  'गवरे',
#  'गिरने',
#  'संगठन',
#  'समाधान',
#  'राजेश',
#  'बस',
#  'दिया',
#  'समेत',
#  '32,485',
#  'ऊधमपुर',
#  'धर्मेन्द्र',
#  'खतरनाक',
#  'स्थाई',
#  'अवगत',
#  'दिवसीय',
#  'खटखटाया',
#  'ऑपरेशन',
#  'नक्शा',
#  'श्रीराम',
#  'चांदी',
#  'कोतवाली',
#  'एकाएक',
#  'दुष्टों',
#  'बमरौली',
#  'जिचकर',
#  'ज्ञानबोधक',
#  'घरों',
#  'सुच्चा',
#  'लोकसभा',
#  'देखते',
#  '6.48',
#  'जाया',
#  'स्वच्छता',
#  'ताकि',
#  'श्रीलंकाई',
#  'आवश्यकता',
#  'खेला',
#  'बीके',
#  'थानाध्यक्ष',
#  'अखिलेश',
#  'विश्वनाथगंज',
#  'अप्रैल',
#  'लौट',
#  'किया',
#  'महावीर',
#  'चलाते',
#  'मौर्य',
#  'अभिभावक',
#  'नवंबर',
#  '28',
#  'संस्थानों',
#  'परेशानी',
#  'भत्ता',
#  'राजनाथ',
#  'संरक्षण',
#  'कॉइन',
#  'मृत',
#  'खोजने',
#  'टैक्स',
#  'संचित',
#  'सरलता',
#  'चलाई',
#  'माहौल',
#  'शाम',
#  'जोर',
#  'मुक्ति',
#  'ग्रामीण',
#  'अस्थिरता',
#  'बताए',
#  'साज',
#  'सीख',
#  'आएं',
#  'हाई',
#  'धरती',
#  '3',
#  'सूर्योदय',
#  'सत्ताधीशों',
#  'कुल्हौरा',
#  'एसीपी',
#  'मीर',
#  'मनाने',
#  'सिलेंडर',
#  'स्वयं',
#  'डॉक्टरों',
#  'जलाने',
#  'कीमत',
#  'विश्वप्रतिष्ठ',
#  'तीखा',
#  'सीरीज',
#  'थोक',
#  'डोडा',
#  'प्रदर्शन',
#  'बयान',
#  'मोइनुद्दीन',
#  'मालिक',
#  'करके',
#  'गिरावट',
#  'एमपी',
#  'तुलना',
#  'राजौरीः',
#  'श्रद्धांजलि',
#  'चौदह',
#  'पर्व',
#  'क्लब',
#  'पंचायत',
#  'श्रीमद्भागवत',
#  'आदेशों',
#  'रोने',
#  'सौ',
#  'प्रदेशाध्यक्ष',
#  '५५',
#  'विभिन्न',
#  'महत्व',
#  'अंबाला',
#  'लिया',
#  'पाटन',
#  'रहने',
#  'पुलिस',
#  'श्रमिक',
#  'सकी',
#  'बंधी',
#  'सात',
#  'बेशक',
#  'औचक',
#  'घेर',
#  'कलाल',
#  'दुकाने',
#  'कर्मी',
#  'प्रेस',
#  'मैंने',
#  'गोपाल',
#  'रखवा',
#  'राज्यव्यापी',
#  'यह',
#  'एमपीपी',
#  'दिनेश',
#  'नगला',
#  'पाए',
#  'सिविल',
#  'बाजार',
#  'और',
#  'जान',
#  'नौजवान',
#  'पक्के',
#  'स्तरों',
#  'आग',
#  'नामकरण',
#  'प्राप्त',
#  'समीक्षा',
#  'उसने',
#  'बाएं',
#  'प्रतिकूल',
#  'खजाने',
#  'बुद्ध',
#  'स्थानीय',
#  'खुशियों',
#  'मंडराती',
#  'सजगता',
#  'अफसरों',
#  'मेहर',
#  'नवविवाहिता',
#  'शुभ',
#  'रकम',
#  'संभावना',
#  'दर्शन',
#  'एंड',
#  'संध्या',
#  'मुंबई',
#  'बच्चों',
#  'चमकेंगी',
#  'मंडल',
#  'कॉफ',
#  'तमाम',
#  'भ्रष्टाचार',
#  'निवासी',
#  'उपलब्ध',
#  'विमर्श',
#  'हम',
#  'बनाकर',
#  'महान',
#  'छापेमारी',
#  'सिक्योरिटी',
#  'रेवेन्यू',
#  'भूमिहीन',
#  'फीसों',
#  'बहुत',
#  'पहुंचने',
#  'कुलदीप',
#  'मेरे',
#  'चांद',
#  ')',
#  'अध्यापक',
#  'निडरता',
#  'कार्यकाल',
#  'बधाई',
#  'निर्माता',
#  'अखिल',
#  'निर्णय',
#  'याकूब',
#  'कदम',
#  'बेहतर',
#  'सदिच्छा',
#  'सूची',
#  'जगाने',
#  'अगुवाई',
#  'चयन',
#  'मिठाई',
#  'मालाएं',
#  'बौखलाते',
#  'गिरोह',
#  'उसका',
#  'पेयजल',
#  'डेलिगेशन',
#  'लटका',
#  'थन्ना',
#  'शिक्षा',
#  'राक्षसों',
#  'गिरीडीह',
#  'बदले',
#  'रंगोली',
#  'आह्वान',
#  'चढ़ाव',
#  'किराएदारों',
#  'भारतीय',
#  'वर्गमीटर',
#  'नाराज़',
#  'सोने',
#  'रखवाने',
#  'मंदिर',
#  'समाज',
#  '(',
#  'सितंबर',
#  'गांव',
#  'बेंगाबाद',
#  'आंकड़ा',
#  'कड़ी',
#  'टारगेट',
#  'पहुंचे',
#  'जोन',
#  'दिलाना',
#  'तुम्हें',
#  'प्रारंभ',
#  'मुताबिक',
#  'डिंडा',
#  'देखा',
#  'इनका',
#  'महानायक',
#  'अमर',
#  'कोमल',
#  'इज',
#  'जराला',
#  'चोटें',
#  ...]

# %% [markdown]
# ## Trigram

# %%
trigram_model = NGramModel(text, 3)
trigram_model.generateText(['के', 'बाद'], 20, top_n=10)
# Out:
# 'के बाद होने लाभ सभ्यता सभ्यता वेस्ट रिवीजन विश्वविद्यालय जब रोगी वेस्ट ओवर रोगी ओवर जब ओवर अकाउंटेंट्स सभ्यता सभ्यता अकाउंटेंट्स लाभ '

# %% [markdown]
# ## Testing the Model

# %%
test_sents, _ = bigram_model._tokenize(test_text)

# %%
testing_set = [sent[1:3] for sent in test_sents]
preds = [bigram_model.generateNextWord(word[:-1], top_n=1) for word in testing_set]
actuals = [word[-1] for word in testing_set]
acc = [1 if pred == actual else 0 for pred, actual in zip(preds, actuals)]
accuracy = sum(acc)/len(acc)
accuracy
# Out:
# 0.4936708860759494

# %%
testing_set = [sent[1:4] for sent in test_sents]
print(testing_set)
preds = [trigram_model.generateNextWord(word[:-1], top_n=1) for word in testing_set]
actuals = [word[-1] for word in testing_set]
acc = [1 if pred == actual else 0 for pred, actual in zip(preds, actuals)]
accuracy = sum(acc)/len(acc)
accuracy
# Out:
# [['उन्होंने', 'इस', 'मामले'], ['गुरुवार', 'को', 'ट्रकों'], ['प्रमुख', 'ने', 'कहा'], ['जिला', 'कलाध्यापक', 'संघ'], ['उन्होंने', 'कहा', 'कि'], ['इसी', 'मौके', 'पर'], ['हमें', 'हीरे', 'की'], ['रात', 'लगभग', 'दो'], ['उन्होंने', 'कहा', 'कि'], ['हिटलर', 'ने', 'आत्मकथा'], ['जागरण', 'संवाद', 'केंद्र'], ['अपने', 'आप', 'से'], ['इसमें', 'राजनीति', 'ही'], ['पंजाब', 'से', 'करीब'], ['उसकी', 'दोनों', 'टांगों'], ['अमेरिकी', 'अर्थव्यवस्था', 'को'], ['अंजली', 'का', 'कहना'], ['तोरा', 'चौकी', 'के'], ['स्कूल', 'प्रबंधक', 'के'], ['प्रभु', 'श्रीराम', 'के'], ['परिवार', 'का', 'कहना'], ['कांग्रेस', 'अपनी', 'विरासत'], ['सीडीपीओ', 'कार्यालय', 'का'], ['पार्टी', 'की', 'जारी'], ['भारतीय', 'जनता', 'पार्टी'], ['शोभन', 'सरकार', 'ने'], ['मतदाता', 'सरकारों', 'से'], ['कन्नूर', 'देश', 'का'], ['कांग्रेसी', 'मित्रों', 'से'], ['अभिभावकों', 'का', 'कहना'], ['हवन', 'व', 'श्रीमद्कथा'], ['पंजाब', 'सरकार', 'ने'], ['इन', 'सभी', 'कर्मचारियों'], ['जांच', 'न्यूनतम', 'ध्वनि'], ['खरीदारों', 'के', 'रुख'], ['हरीश', '10वीं', 'की'], ['इस', 'पर', 'नकेल'], ['भाजपा', 'के', 'पीएम'], ['उनके', 'नाम', 'पर'], ['गंगा', 'अपनी', 'बहन'], ['बाम्बे', 'स्टॉक', 'एक्सचेंज'], ['कई', 'आवेदक', 'ऐसे'], ['दोनों', 'कीमती', 'धातुओं'], ['सूची', 'में', 'वे'], ['उन्हें', 'महिला', 'अधिकारियों'], ['इस', 'सब', 'के'], ['डीएसपी', 'कुलभूषण', 'वर्मा'], ['कांग्रेस', 'को', 'इस'], ['भाजपा', 'द्वारा', 'जिन'], ['भारत', 'के', 'इतिहास'], ['इस', 'दौरान', 'आपूर्ति'], ['प्रबंधक', 'समिति', 'के'], ['मां', 'का', 'कहना'], ['तब', 'तक', 'अंजली'], ['शोभन', 'सरकार', 'ने'], ['जिसका', 'मास्टर', 'माइंड'], ['कोटरंका', 'अस्पताल', 'में'], ['परिवार', 'में', 'दो'], ['रैली', 'बाड़वाला', 'से'], ['संघ', 'के', 'प्रदेशाध्यक्ष'], ['इंस्पेक्टर', 'ताजगंज', 'हरी'], ['समारोह', 'में', 'पूर्व'], ['बड़ा', 'झूठ', 'ज्यादा'], ['ज्ञात', 'हो', 'कि'], ['उसी', 'समय', 'से'], ['तीन', 'सीटों', 'के'], ['ऋग्वेद', 'के', "'"], ['देहरादून', 'मार्ग', 'स्थित'], ['प्रतापगढ़', 'जिले', 'के'], ['कई', 'पश्चिमी', 'देशों'], ['हैलोवीन', 'पार्टियों', 'में'], ['किशोरी', 'के', 'घरवालों'], ['पुलिस', 'ने', 'गंगा'], ['ऊधमपुर', 'से', 'आने'], ['सुशील', 'विश्वकर्मा', 'के'], ['मनपा', 'शिक्षक', 'संघ'], ['बैठक', 'में', 'सांसद'], ['रिन्युअल', 'व', 'पक्के'], ['शव', 'को', 'मोरचरी'], ['मूल्यवान', 'धातुओं', 'का'], ['यहां', 'तक', 'की'], ['मोटर', 'वाहन', 'दुर्घटना'], ['हादसे', 'में', 'मृत'], ['पहला', 'और', 'दूसरा'], ['स्कूल', 'और', 'कॉलेजों'], ['कहा', 'कि', 'पंसस'], ['बच्ची', 'की', 'मां'], ['इस', 'दौरान', 'कोटरंका'], ['इन', 'अधिकारियों', 'को'], ['शनिवार', 'को', 'कथा'], ['गांधी', 'नगर', 'पटेल'], ['यही', 'नहीं', 'कई'], ['भारत', 'के', 'लोगों'], ['योजनाओं', 'के', 'नामकरण'], ['रेलवे', 'के', 'सीपीआरओ'], ['नक्शा', 'जमा', 'करने'], ['इस', 'साल', 'अक्टूबर'], ['उपभोक्ता', 'परेशान', 'हैं'], ['उल्लेखनीय', 'है', 'कि'], ['भारत', 'में', 'इनका'], ['जिन्होंने', 'बिजली', 'का'], ['जी', 'हां', 'इस'], ['उन्होंने', 'अपनी', 'युक्ति'], ['वह', 'लंबे', 'समय'], ['सार्वजनिक', 'वितरण', 'प्रणाली'], ['इसीलिए', 'सभी', 'सब'], ['उनकी', 'मौत', 'से'], ['फेडरेशन', 'ऑफ', 'यूटी'], ['31', 'अक्टूबर', 'इस'], ['किराएदारों', 'को', 'स्टे'], ['पटाखे', 'की', 'दुकान'], ['बहरहाल', 'एक', 'दिवसीय'], ['तेज', 'रफ्तार', 'जीप'], ['नंगल', 'के', 'दीपक'], ['इसी', 'तरह', 'दिवाली'], ['परिवार', 'ने', 'मुआवजे'], ['उनका', 'निधन', 'भी'], ['प्रधानाध्यापक', 'संध्या', 'मेडपल्लीवार'], ['वहीं', 'वीरवार', 'दिनभर'], ['पार्षद', 'व', 'पुलिस'], ['पांच', 'राज्यों', 'के'], ['उन्होंने', 'कहा', 'कि'], ['घर', 'वाले', 'बाजार'], ['उत्तार', 'प्रदेश', 'में'], ['कांग्रेस', 'कभी', 'लोकतांत्रिक'], ['1950', 'के', 'बाद'], ['नागरिक', 'अस्पताल', 'सुंदरनगर'], ['बर्तन', 'विक्रेता', 'काली'], ['हालांकि', 'अधिकारियों', 'ने'], ['एसोसिएशन', 'ऑफ', 'सीनियर्स'], ['घटना', 'को', 'देखते'], ['देहरादून', 'मार्ग', 'पर'], ['मुख्यमंत्री', 'अखिलेश', 'यादव'], ['परेशानी', 'का', 'एक'], ['सरकार', 'को', 'इस'], ['उन्होंने', 'सभी', 'राज्यों'], ['कार्यक्रम', 'में', 'प्रबंधक'], ['ऑल', 'इडिया', 'जेम्स'], ["'", '\nदेश', 'का'], ['फिलहाल', 'वह', 'बेरोजगार'], ['प्रमुख', 'ने', 'बीते'], ['रूपनगर', 'विजिलेंस', 'ब्यूरो'], ['वह', 'आदेश', 'भी'], ['जिनकी', 'सुरक्षा', 'को'], ['यहां', 'तरह', '-'], ['उसका', 'शव', 'नाले'], ['इसके' ...
# 0.8227848101265823

# %%
trigram_model.generateText(['उन्होंने', 'इस'], length=100)
# Out:
# 'उन्होंने इस मामले सभ्यता वेस्ट वेस्ट संवैधानिक संवैधानिक सभ्यता सभ्यता सभ्यता संवैधानिक वेस्ट वेस्ट संवैधानिक सभ्यता सभ्यता वेस्ट वेस्ट सभ्यता वेस्ट वेस्ट सभ्यता वेस्ट वेस्ट सभ्यता सभ्यता सभ्यता संवैधानिक संवैधानिक संवैधानिक संवैधानिक संवैधानिक वेस्ट वेस्ट संवैधानिक वेस्ट सभ्यता संवैधानिक वेस्ट सभ्यता संवैधानिक वेस्ट सभ्यता वेस्ट वेस्ट वेस्ट वेस्ट संवैधानिक सभ्यता सभ्यता सभ्यता वेस्ट सभ्यता संवैधानिक सभ्यता सभ्यता सभ्यता संवैधानिक संवैधानिक वेस्ट वेस्ट सभ्यता संवैधानिक संवैधानिक वेस्ट वेस्ट वेस्ट सभ्यता सभ्यता वेस्ट वेस्ट वेस्ट वेस्ट सभ्यता सभ्यता सभ्यता वेस्ट सभ्यता सभ्यता वेस्ट सभ्यता संवैधानिक सभ्यता वेस्ट सभ्यता सभ्यता सभ्यता सभ्यता वेस्ट सभ्यता संवैधानिक वेस्ट संवैधानिक सभ्यता सभ्यता सभ्यता सभ्यता सभ्यता सभ्यता सभ्यता सभ्यता '
